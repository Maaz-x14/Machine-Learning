# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('USA Housing Dataset.csv')
print(data.shape)
data.head()
# Out:
# (4140, 18)
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-09 00:00:00   376000.0       3.0       2.00         1340      1384
# 1  2014-05-09 00:00:00   800000.0       4.0       3.25         3540    159430
# 2  2014-05-09 00:00:00  2238888.0       5.0       6.50         7270    130017
# 3  2014-05-09 00:00:00   324000.0       3.0       2.25          998       904
# 4  2014-05-10 00:00:00   549900.0       5.0       2.75         3060      7015
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     3.0           0     0          3        1340              0      2008
# 1     2.0           0     0          3        3540              0      2007
# 2     2.0           0     0          3        6420            850      2010
# 3     2.0           0     0          3         798            200      2007
# 4     1.0           0     0          5        1600           1460      1979
#
# ...

# %%
data.iloc[0]
# Out:
# date                 2014-05-09 00:00:00
# price                           376000.0
# bedrooms                             3.0
# bathrooms                            2.0
# sqft_living                         1340
# sqft_lot                            1384
# floors                               3.0
# waterfront                             0
# view                                   0
# condition                              3
# sqft_above                          1340
# sqft_basement                          0
# yr_built                            2008
# yr_renovated                           0
# street           9245-9249 Fremont Ave N
# city                             Seattle
# statezip                        WA 98103
# country                              USA
# Name: 0, dtype: object

# %%
data.iloc[12:16 , 4:8]
# Out:
#     sqft_living  sqft_lot  floors  waterfront
# 12         2830      5000     2.0           0
# 13         2010      2287     2.0           0
# 14         3300     12090     2.0           0
# 15         1230      1391     2.0           0

# %%
# Masking the data from the data frame
mask1 = data['city'] == 'Issaquah'
mask2 = data['yr_built'] > 2000
data[mask1 & mask2]
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 2     2014-05-09 00:00:00  2.238888e+06       5.0       6.50         7270
# 13    2014-05-12 00:00:00  4.532460e+05       3.0       2.50         2010
# 54    2014-05-12 00:00:00  7.880000e+05       4.0       3.25         3680
# 89    2014-05-13 00:00:00  7.570000e+05       3.0       3.25         3190
# 97    2014-05-13 00:00:00  7.770000e+05       3.0       3.25         3610
# ...                   ...           ...       ...        ...          ...
# 3700  2014-07-08 00:00:00  8.120000e+05       4.0       3.50         3370
# 3811  2014-07-09 00:00:00  5.300000e+05       3.0       2.50         1790
# 3843  2014-07-10 00:00:00  7.350000e+05       3.0       2.50         2820
# 3904  2014-05-07 00:00:00  5.003240e+05       3.0       2.50         2280
# 4126  2014-07-07 00:00:00  4.302778e+05       3.0       2.25         1620
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
data['bedrooms'].value_counts()   # returns frequency of each item of categorical data
# Out:
# bedrooms
# 3.0    1833
# 4.0    1382
# 2.0     500
# 5.0     317
# 6.0      56
# 1.0      37
# 7.0      11
# 8.0       2
# 0.0       2
# Name: count, dtype: int64

# %%
print("Number of cols: " ,data.shape[1])
print("Number of rows: " ,data.shape[0])
# Out:
# Number of cols:  18
# Number of rows:  4140

# %%
data['bedrooms'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='bedrooms'>

# %%
cities = data['city'].value_counts()
cities.index
# Out:
# Index(['Seattle', 'Renton', 'Bellevue', 'Redmond', 'Kent', 'Kirkland',
#        'Auburn', 'Issaquah', 'Sammamish', 'Federal Way', 'Shoreline',
#        'Woodinville', 'Maple Valley', 'Mercer Island', 'Snoqualmie', 'Burien',
#        'Kenmore', 'Des Moines', 'North Bend', 'Covington', 'Duvall',
#        'Lake Forest Park', 'Newcastle', 'Bothell', 'SeaTac', 'Vashon',
#        'Tukwila', 'Enumclaw', 'Carnation', 'Normandy Park', 'Medina',
#        'Clyde Hill', 'Fall City', 'Black Diamond', 'Pacific', 'Yarrow Point',
#        'Ravensdale', 'Preston', 'Milton', 'Skykomish', 'Snoqualmie Pass',
#        'Beaux Arts Village', 'Algona'],
#       dtype='object', name='city')

# %%
cities.values
# Out:
# array([1415,  261,  260,  209,  167,  166,  162,  162,  158,  131,  112,
#         103,   90,   81,   65,   64,   58,   52,   45,   39,   39,   33,
#          31,   30,   29,   28,   28,   28,   18,   16,   11,   10,    9,
#           7,    6,    4,    4,    2,    2,    2,    1,    1,    1])

# %%
print(cities.tail())
cities.head()
# Out:
# city
# Milton                2
# Skykomish             2
# Snoqualmie Pass       1
# Beaux Arts Village    1
# Algona                1
# Name: count, dtype: int64
# city
# Seattle     1415
# Renton       261
# Bellevue     260
# Redmond      209
# Kent         167
# Name: count, dtype: int64

# %%
cities['Kent']
# Out:
# 167

# %%
cities['Kent'] + cities['Redmond']
# Out:
# 376

# %%
(data['bedrooms'].value_counts() + data['bathrooms'].value_counts()).sort_values(ascending=False)
# Out:
# 3.00    1979.0
# 4.00    1403.0
# 2.00     876.0
# 1.00     712.0
# 5.00     322.0
# 0.00       4.0
# 0.75       NaN
# 1.25       NaN
# 1.50       NaN
# 1.75       NaN
# 2.25       NaN
# 2.50       NaN
# 2.75       NaN
# 3.25       NaN
# 3.50       NaN
# 3.75       NaN
# 4.25       NaN
# 4.50       NaN
# 4.75       NaN
# 5.25       NaN
# 5.50       NaN
# 6.00       NaN
# 6.25       NaN
# 6.50       NaN
# 6.75       NaN
# 7.00       NaN
# 8.00       NaN
# Name: count, dtype: float64

# %%
data.sort_values(['price','bathrooms','bedrooms','sqft_above'],ascending=[False,False,False,False])
# Out:
#                      date       price  bedrooms  bathrooms  sqft_living  \
# 3890  2014-07-03 00:00:00  26590000.0       3.0       2.00         1180
# 3886  2014-06-23 00:00:00  12899000.0       3.0       2.50         2190
# 1826  2014-06-11 00:00:00   7062500.0       5.0       4.50        10040
# 2194  2014-06-17 00:00:00   4668000.0       5.0       6.75         9640
# 2301  2014-06-18 00:00:00   4489000.0       4.0       3.00         6430
# ...                   ...         ...       ...        ...          ...
# 4027  2014-06-12 00:00:00         0.0       4.0       1.00         2080
# 4114  2014-07-02 00:00:00         0.0       3.0       1.00         1520
# 3993  2014-06-03 00:00:00         0.0       3.0       1.00         1300
# 4094  2014-06-27 00:00:00         0.0       2.0       1.00          810
# 3982  2014-06-02 00:00:00         0.0       1.0       1.00          720
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
data.drop_duplicates(subset='floors',keep='last',inplace=False)
# Out:
#                      date     price  bedrooms  bathrooms  sqft_living  \
# 2938  2014-06-25 00:00:00  563500.0       3.0       2.50         1400
# 3938  2014-05-19 00:00:00  195000.0       5.0       3.75         5340
# 4125  2014-07-07 00:00:00  486895.0       3.0       1.00         1890
# 4128  2014-07-08 00:00:00       0.0       4.0       2.25         2890
# 4138  2014-07-10 00:00:00  203400.0       4.0       2.00         2090
# 4139  2014-07-10 00:00:00  220600.0       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 2938      1312     3.5           0     0          3        1400
# 3938     10655     2.5           0     3          4        3740
# 4125      3330     1.5           0     0          4        1390
# 4128     18226     3.0           1     4          3        2890
# 4138      6630     1.0           0     0          3        1070
# 4139      8102     2.0           0     0          4        1490
#
# ...

# %%
floors = data.groupby('floors')
floors

# %%
floors.last()
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# floors
# 1.0     2014-07-10 00:00:00  203400.0       4.0       2.00         2090
# 1.5     2014-07-07 00:00:00  486895.0       3.0       1.00         1890
# 2.0     2014-07-10 00:00:00  220600.0       3.0       2.50         1490
# 2.5     2014-05-19 00:00:00  195000.0       5.0       3.75         5340
# 3.0     2014-07-08 00:00:00       0.0       4.0       2.25         2890
# 3.5     2014-06-25 00:00:00  563500.0       3.0       2.50         1400
#
#         sqft_lot  waterfront  view  condition  sqft_above  sqft_basement  \
# floors
# 1.0         6630           0     0          3        1070           1020
# 1.5         3330           0     0          4        1390            500
# 2.0         8102           0     0          4        1490              0
# 2.5        10655           0     3          4        3740           1600
# 3.0        18226           1     4          3        2890              0
# ...

# %%
floors.groups
# Out:
# {1.0: [4, 6, 7, 11, 17, 19, 21, 22, 24, 27, 29, 31, 32, 33, 36, 39, 40, 41, 43, 44, 45, 49, 52, 55, 56, 57, 59, 62, 63, 65, 67, 68, 69, 71, 72, 74, 88, 90, 91, 92, 93, 94, 98, 99, 100, 101, 102, 103, 105, 106, 109, 111, 112, 114, 117, 122, 124, 125, 126, 127, 128, 129, 132, 133, 135, 139, 140, 141, 142, 143, 144, 145, 148, 149, 152, 153, 154, 155, 156, 165, 166, 168, 170, 173, 174, 176, 177, 178, 179, 180, 181, 182, 183, 184, 186, 188, 198, 200, 201, 204, ...], 1.5: [16, 18, 23, 25, 35, 46, 51, 58, 60, 66, 73, 75, 108, 113, 123, 134, 136, 171, 185, 189, 195, 196, 199, 203, 211, 219, 227, 244, 260, 264, 273, 297, 327, 331, 343, 360, 363, 371, 398, 403, 404, 406, 408, 409, 413, 417, 430, 435, 439, 467, 476, 486, 508, 515, 525, 527, 529, 563, 569, 608, 618, 654, 699, 702, 721, 731, 734, 740, 758, 766, 767, 773, 789, 796, 803, 812, 814, 824, 829, 835, 840, 850, 864, 867, 871, 887, 898, 902, 916, 919, 928, 945, 961, 967, 983, 987, 1012, 1017, 1029, 1031, ...], 2.0: [1, 2, 3, 5, 10, 12, 13
# ...
