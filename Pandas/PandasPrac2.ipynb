# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('USA Housing Dataset.csv')
data
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-09 00:00:00  3.760000e+05       3.0       2.00         1340
# 1     2014-05-09 00:00:00  8.000000e+05       4.0       3.25         3540
# 2     2014-05-09 00:00:00  2.238888e+06       5.0       6.50         7270
# 3     2014-05-09 00:00:00  3.240000e+05       3.0       2.25          998
# 4     2014-05-10 00:00:00  5.499000e+05       5.0       2.75         3060
# ...                   ...           ...       ...        ...          ...
# 4135  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4136  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4137  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4138  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4139  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
data['city'].value_counts().plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
price = data.groupby('price')
print("Maximum price is: ",data['price'].max())
print("Minimum price is: ",data['price'].min())
print("Average price is:",data['price'].mean())
# Out:
# Maximum price is:  26590000.0
# Minimum price is:  0.0
# Average price is: 553062.8772890784

# %%
data.sort_values(['price','sqft_living'],ascending=[True,False])
# Out:
#                      date       price  bedrooms  bathrooms  sqft_living  \
# 4115  2014-07-02 00:00:00         0.0       5.0       6.25         8020
# 4063  2014-06-23 00:00:00         0.0       3.0       4.50         5230
# 3925  2014-05-13 00:00:00         0.0       4.0       4.50         5030
# 3922  2014-05-12 00:00:00         0.0       5.0       4.50         4630
# 4068  2014-06-24 00:00:00         0.0       4.0       5.00         4550
# ...                   ...         ...       ...        ...          ...
# 2301  2014-06-18 00:00:00   4489000.0       4.0       3.00         6430
# 2194  2014-06-17 00:00:00   4668000.0       5.0       6.75         9640
# 1826  2014-06-11 00:00:00   7062500.0       5.0       4.50        10040
# 3886  2014-06-23 00:00:00  12899000.0       3.0       2.50         2190
# 3890  2014-07-03 00:00:00  26590000.0       3.0       2.00         1180
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
newDf = data.drop_duplicates('city')
newDf.shape
# Out:
# (43, 18)

# %%
cities = data.groupby('city')
cities.first()
# Out:
#                                    date      price  bedrooms  bathrooms  \
# city
# Algona              2014-05-30 00:00:00   196440.0       3.0       2.00
# Auburn              2014-05-12 00:00:00   560000.0       3.0       2.00
# Beaux Arts Village  2014-05-28 00:00:00   745000.0       3.0       1.75
# Bellevue            2014-05-12 00:00:00   900000.0       4.0       3.25
# Black Diamond       2014-05-22 00:00:00   398000.0       2.0       1.00
# Bothell             2014-05-16 00:00:00   551000.0       2.0       2.00
# Burien              2014-05-12 00:00:00   330000.0       5.0       3.00
# Carnation           2014-05-09 00:00:00   800000.0       4.0       3.25
# Clyde Hill          2014-05-12 00:00:00   927000.0       4.0       2.75
# Covington           2014-05-13 00:00:00   450000.0       3.0       2.25
# Des Moines          2014-05-14 00:00:00   175000.0       2.0       1.00
# Duvall              2014-05-12 00:00:00   540000.0       4.0       2.25
# ...

# %%
cities.get_group('Bellevue')
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 20    2014-05-12 00:00:00  9.000000e+05       4.0       3.25         4700
# 22    2014-05-12 00:00:00  1.575000e+06       5.0       2.75         3650
# 26    2014-05-12 00:00:00  7.500000e+05       4.0       2.50         2980
# 70    2014-05-12 00:00:00  7.460000e+05       3.0       2.50         2620
# 77    2014-05-12 00:00:00  1.264000e+06       4.0       3.75         3490
# ...                   ...           ...       ...        ...          ...
# 4114  2014-07-02 00:00:00  0.000000e+00       3.0       1.00         1520
# 4115  2014-07-02 00:00:00  0.000000e+00       5.0       6.25         8020
# 4123  2014-07-07 00:00:00  2.827667e+05       4.0       2.00         1700
# 4124  2014-07-07 00:00:00  4.864458e+05       3.0       1.75         1880
# 4136  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
cities.sum('sqft_living')
# Out:
#                            price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# city
# Algona              1.964400e+05       3.0       2.00         1560      7352
# Auburn              4.805847e+07     550.0     338.25       323210   4022869
# Beaux Arts Village  7.450000e+05       3.0       1.75         1490      9800
# Bellevue            2.240255e+08     991.0     646.50       713385   3620437
# Black Diamond       2.568500e+06      23.0      13.00        14160    204990
# Bothell             1.439008e+07     106.0      72.25        69770    267522
# Burien              2.222240e+07     212.0     113.00       117570    802256
# Carnation           9.541543e+06      56.0      38.75        42344   1180502
# Clyde Hill          1.343140e+07      42.0      27.25        37520    202673
# Covington           1.177491e+07     130.0      77.00        70380    487545
# Des Moines          1.605772e+07     168.0      97.75        94862    546391
# ...

# %%
cities[''.mean('price')
# Out:
#                            price  bedrooms  bathrooms  sqft_living  \
# city
# Algona              1.964400e+05  3.000000   2.000000  1560.000000
# Auburn              2.966572e+05  3.395062   2.087963  1995.123457
# Beaux Arts Village  7.450000e+05  3.000000   1.750000  1490.000000
# Bellevue            8.616365e+05  3.811538   2.486538  2743.788462
# Black Diamond       3.669286e+05  3.285714   1.857143  2022.857143
# Bothell             4.796694e+05  3.533333   2.408333  2325.666667
# Burien              3.472249e+05  3.312500   1.765625  1837.031250
# Carnation           5.300857e+05  3.111111   2.152778  2352.444444
# Clyde Hill          1.343140e+06  4.200000   2.725000  3752.000000
# Covington           3.019207e+05  3.333333   1.974359  1804.615385
# Des Moines          3.088023e+05  3.230769   1.879808  1824.269231
# Duvall              4.084065e+05  3.410256   2.275641  2201.666667
# Enumclaw            3.076146e+05  3.178571   1.758929  1922.500000
# ...
